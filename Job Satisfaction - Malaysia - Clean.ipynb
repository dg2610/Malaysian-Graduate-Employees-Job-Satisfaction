# %%
import pandas as pd

# Load your dataset
df = pd.read_excel("Education and Career Pathway Survey.xlsx")

df.head()
# Out:
#                 Timestamp  What is your age? What is your Gender?  \
# 0 2025-01-02 19:42:36.689  26 - 30 years old               Female
# 1 2025-01-02 19:54:28.084  20 - 25 years old                 Male
# 2 2025-01-02 19:58:13.712  26 - 30 years old               Female
# 3 2025-01-02 20:00:58.948      35+ years old               Female
# 4 2025-01-02 20:11:24.466  20 - 25 years old               Female
#
#   Which city are you from? What is your highest education?  \
# 0                   Kajang               Bachelor's Degree
# 1                   CHERAS                 Master's Degree
# 2             sungai boloh                 Master's Degree
# 3            PETALING JAYA                             SPM
# 4                   kajang               Bachelor's Degree
#
#     What is your field of Study/Major?  \
# 0  Business, Management, and Marketing
# 1  Business, Management, and Marketing
# 2  Business, Management, and Marketing
# 3         Medicine and Health Sciences
# ...

# %%
# Simplified column names mapping
column_mapping = {
    "What is your age?": "Age",
    "What is your Gender?": "Gender",
    "Which city are you from?": "City",
    "What is your highest education?": "Education",
    " What is your field of Study/Major?": "Major",
    " What is your current employment status?": "Employment_Status",
    "What is the industry/sector of employment?": "Industry",
    "What is your Job Title?": "Job_Title",
    "What are the skill required for your current job? (Separate skills by comma)": "Skills",
    "How many work experience do you have?": "Experience",
    "What is your overall job satisfaction?": "Satisfaction",
    "What is the reason for your job satisfaction/dissatisfaction?": "Satisfaction_Reason",
    "What factor influencing your career choice?": "Career_Factors",
    "Would You Change Your Career Path if Given a Chance? ": "Change_Career",
    "Do you feel that your current job provides you with opportunities to use and develop your skills?  ": "Develop_Skills",
    "What type of support would you need for a career transition? ": "Support_Needed",
    "Have you experienced any skills gap between your education and your current job requirements?  ": "Skills_Gap",
    "Do you feel that your current job aligns with your long-term career goals?  ": "Align_Goals",
    "If you were to transition to a new career, what type of roles or industries would you be interested in?  (If more than 1, separate using comma)": "Desired_Roles",
    "Would you find it helpful to have personalized career recommendations based on your skills and interests?  ": "Career_Recommendations",
    "What barriers do you perceive in transitioning to a new career? (Select all that apply)  ": "Career_Barriers",
    "What kind of resources or support would you find most useful when considering a career change?  ": "Support_Resources"
}

# Rename columns
df.rename(columns=column_mapping, inplace=True)

# Check the updated columns
print(df.columns)
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Education', 'Major',
#        'Employment_Status', 'Industry', 'Job_Title', 'Skills', 'Experience',
#        'Satisfaction', 'Satisfaction_Reason', 'Career_Factors',
#        'Change_Career', 'Develop_Skills', 'Support_Needed', 'Skills_Gap',
#        'Align_Goals', 'Desired_Roles', 'Career_Recommendations',
#        'Career_Barriers', 'Support_Resources'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 278 entries, 0 to 277
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               278 non-null    datetime64[ns]
#  1   Age                     278 non-null    object
#  2   Gender                  278 non-null    object
#  3   City                    277 non-null    object
#  4   Education               278 non-null    object
#  5   Major                   278 non-null    object
#  6   Employment_Status       278 non-null    object
#  7   Industry                278 non-null    object
#  8   Job_Title               268 non-null    object
#  9   Skills                  258 non-null    object
#  10  Experience              278 non-null    object
#  11  Satisfaction            278 non-null    object
#  12  Satisfaction_Reason     278 non-null    object
#  13  Career_Factors          278 non-null    object
# ...

# %%
# Remove the timestamp column
df = df.drop(columns=['Timestamp'])

# Preview the dataset after removing the column
print(df.head())
# Out:
#                  Age  Gender           City          Education  \
# 0  26 - 30 years old  Female         Kajang  Bachelor's Degree
# 1  20 - 25 years old    Male         CHERAS    Master's Degree
# 2  26 - 30 years old  Female   sungai boloh    Master's Degree
# 3      35+ years old  Female  PETALING JAYA                SPM
# 4  20 - 25 years old  Female         kajang  Bachelor's Degree
#
#                                  Major Employment_Status  \
# 0  Business, Management, and Marketing          Employed
# 1  Business, Management, and Marketing          Employed
# 2  Business, Management, and Marketing          Employed
# 3         Medicine and Health Sciences          Employed
# 4                            Education          Employed
#
#                                   Industry           Job_Title  \
# 0                  Hospitality and Tourism  Call Centre Agent
# 1  Media, Entertainment, and Communication    Customer service
# ...

# %%
# Display value counts for each column
for column in df.columns:
    print(f"Value counts for {column}:\n")
    print(df[column].value_counts())
    print("\n" + "-"*50 + "\n")
# Out:
# Value counts for Age:
#
# Age
# 20 - 25 years old    172
# 26 - 30 years old     64
# 35+ years old         23
# 31 - 35 years old     19
# Name: count, dtype: int64
#
# --------------------------------------------------
#
# Value counts for Gender:
#
# Gender
# Female    145
# Male      133
# Name: count, dtype: int64
#
# --------------------------------------------------
#
# Value counts for City:
#
# City
# Selangor            34
# Rawang              26
# Kajang              21
# Cheras              15
# Kl                  15
#                     ..
# Malaysia             1
# kota damansara       1
# Kuala lumpur(KL)     1
# Banting              1
# serdang              1
# Name: count, Length: 77, dtype: int64
#
# --------------------------------------------------
#
# Value counts for Education:
#
# Education
# Diploma              92
# SPM                  87
# Bachelor's Degree    80
# Master's Degree      16
# PhD                   3
# Name: count, dtype: int64
#
# ...

# %%
# Lowercase and strip spaces
df['City'] = df['City'].str.lower().str.strip()

# Replace abbreviations and typos
city_replacements = {
    'kl': 'kuala lumpur',
    'kuala lumpur(kl)': 'kuala lumpur',
    'petaling jaya': 'petaling jaya',
    'george town': 'george town',
    'bukit jalil': 'bukit jalil',
    'cheras': 'cheras',
    'kajang': 'kajang',
    'kakang':'kajang',
    'rawang': 'rawang',
    'selangor': 'selangor',
    'kajang, selangor': 'kajang',
    'bukit  jalil': 'bukit jalil',
    'n9':'negeri sembilan',
    'pj':'petaling jaya',
    'hr management':'unknown',
    'customer service agent':'unknown',  
    'selangor ampang':'ampang',
    'malaysia':'unknown',
}

df['City'] = df['City'].replace(city_replacements)

# Re-check value counts
city_counts = df['City'].value_counts()
print(city_counts)
# Out:
# City
# selangor            42
# kuala lumpur        42
# kajang              36
# rawang              30
# cheras              18
# petaling jaya       16
# seremban            14
# bangsar             12
# george town          8
# ampang               7
# ipoh                 5
# unknown              4
# klang                4
# gombak               4
# puchong              3
# bukit jalil          3
# shah alam            3
# sabah                2
# pahang               2
# melaka               2
# negeri sembilan      2
# putrajaya            2
# kota damansara       1
# labu, seremban       1
# kajang selangor      1
# service crew         1
# sandakan             1
# johor bahru          1
# kedah                1
# malaysian            1
# sungai buloh         1
# tampin               1
# sungai boloh         1
# genting highland     1
# pulau pinang         1
# kota kinabalu        1
# banting              1
# serdang              1
# Name: count, dtype: int64

# %%
city_to_state = {
    'kuala lumpur': 'Kuala Lumpur',
    'selangor': 'Selangor',
    'kajang': 'Selangor',
    'cheras': 'Selangor',
    'petaling jaya': 'Selangor',
    'seremban': 'Negeri Sembilan',
    'bangsar': 'Kuala Lumpur',
    'george town': 'Penang',
    'rawang': 'Selangor',
    'ipoh': 'Perak',
    'klang': 'Selangor',
    'bukit jalil': 'Kuala Lumpur',
    'gombak': 'Selangor',
    'sabah': 'Sabah',
    'melaka': 'Melaka',
    'puchong': 'Selangor',
    'putrajaya': 'Putrajaya',
    'negeri sembilan': 'Negeri Sembilan',
    'pahang': 'Pahang',
    'genting highland': 'Pahang',
    'penang': 'Penang',
    'ampang': 'Selangor',
    'kota kinabalu': 'Sabah',
    'banting': 'Selangor',
    'kota damansara': 'Selangor',
    'sungai boloh': 'Selangor',
    'shah alam': 'Selangor',
    'tampin': 'Negeri Sembilan',
    'pulau pinang':'Penang',
    'unknown': 'Unknown',
    'johor bahru':'Johor',
    'serdang':'Selangor',
    'labu, seremban':'Negeri Sembilan',
    'kajang selangor':'Selangor',
    'sandakan':'Sabah',
    'sungai buloh':'Selangor',
    'malaysian': 'Unknown',
    'service crew': 'Unknown'
}

# Replace city names with states
df['State'] = df['City'].str.lower().replace(city_to_state)

# Check the updated counts by state
state_counts = df['State'].value_counts()
print(state_counts)
# Out:
# State
# Selangor           169
# Kuala Lumpur        57
# Negeri Sembilan     18
# Penang               9
# Unknown              6
# Perak                5
# Sabah                4
# Pahang               3
# Putrajaya            2
# Melaka               2
# kedah                1
# Johor                1
# Name: count, dtype: int64

# %%
# Remove the city column
df = df.drop(columns=['City'])

# Preview the dataset after removing the column
print(df.head())
# Out:
#                  Age  Gender          Education  \
# 0  26 - 30 years old  Female  Bachelor's Degree
# 1  20 - 25 years old    Male    Master's Degree
# 2  26 - 30 years old  Female    Master's Degree
# 3      35+ years old  Female                SPM
# 4  20 - 25 years old  Female  Bachelor's Degree
#
#                                  Major Employment_Status  \
# 0  Business, Management, and Marketing          Employed
# 1  Business, Management, and Marketing          Employed
# 2  Business, Management, and Marketing          Employed
# 3         Medicine and Health Sciences          Employed
# 4                            Education          Employed
#
#                                   Industry           Job_Title  \
# 0                  Hospitality and Tourism  Call Centre Agent
# 1  Media, Entertainment, and Communication    Customer service
# 2  Media, Entertainment, and Communication         Team leader
# 3  Media, Entertainment, and Communication        data analyst
# ...

# %%
# Get the value counts
job_title_counts = df['Job_Title'].value_counts()

# Print each job title and count
for job, count in job_title_counts.items():
    print(f"{job}: {count}")
# Out:
# Customer service agent: 29
# Customer service : 14
# Na: 10
# Service crew: 10
# Grab driver: 5
# Team leader: 5
# Teacher: 5
# -: 5
# Nurse: 4
# Accountant: 4
# Team leader : 3
# Grab driver : 3
# Actor: 3
# Doctor: 3
# Customer service agent : 3
# Admin: 3
# Customer service: 3
# Accountant : 3
# Manager: 3
#  Customer service agent: 3
# Supervisor : 2
# Grab food driver: 2
# Customer service Agent: 2
# nurse: 2
# Chef: 2
# Customer service agent executive : 2
# Medical insurance agent: 1
# Counsellor : 1
# Kriti Fashion Tailoring : 1
# Senior Physiotherapist : 1
# Online business++: 1
# Own business : 1
# TEA LADY: 1
# Paper work hr: 1
# Director : 1
#  Warehouse Operator: 1
# Area Manager : 1
# Delivery : 1
# Maintenance : 1
# Behaviour therapist : 1
# Restaurant & Bar Operation Manager: 1
# non: 1
# Manager : 1
# Sevice crew: 1
# Service crew (pizzahut): 1
# Music Director & Music Teacher: 1
# Sales : 1
# Graphic designer : 1
# Administrative executive : 1
# ...

# %%
# Lowercase and strip spaces
df['Job_Title'] = df['Job_Title'].str.lower().str.strip()

job_title_mapping = {
    'medical insurance agent': 'insurance agent',
    'counsellor': 'healthcare professional',
    'kriti fashion tailoring': 'fashion & textile',
    'senior physiotherapist': 'healthcare professional',
    'online business++': 'entrepreneur',
    'own business': 'entrepreneur',
    'tea lady': 'hospitality staff',
    'paper work hr': 'hr & recruitment',
    'director': 'director',
    'warehouse operator': 'warehouse staff',
    'area manager': 'manager',
    'delivery': 'delivery driver',
    'maintenance': 'maintenance staff',
    'behaviour therapist': 'healthcare professional',
    'restaurant & bar operation manager': 'hospitality staff',
    'non': 'unemployed',
    '-': 'unemployed',
    'na': 'unemployed',
    'manager': 'manager',
    'sevice crew': 'service crew',
    'service crew (pizzahut)': 'service crew',
    'music director & music teacher': 'music & arts',
    'sales': 'sales agent',
    'graphic designer': 'graphic designer',
    'administrative executive': 'admin',
    'senior business support executive': 'business support',
    'office admin': 'admin',
    'doctor': 'doctor',
    'aircraft engineer': 'engineer',
    'call centre agent': 'customer service agent',
    'service crw': 'service crew',
    'hostess': 'hospitality staff',
    'service crew': 'service crew',
    'marketing': 'marketing executive',
    'caring pharmacy': 'pharmacy staff',
    'cx trainer': 'trainer',
    'customer executive': 'customer service agent',
    'singer songwriter': 'media & content creator',
    'assessor': 'hr & recruitment',
    'secretary': 'admin',
    'hiring manager': 'hr & recruitment',
    'cashier': 'retail staff',
    'technician': 'technician',
    'clinical laboratory scientist': 'healthcare professional',
    'data analytics': 'data analyst',
    'editor': 'media & content creator',
    'influncer': 'media & content creator',
    'service crew (mcd)': 'service crew',
    'intern': 'intern',
    'videographer/editor': 'media & content creator',
    'delivery guy(pizzahut)': 'delivery driver',
    'pizzahut delivry guy': 'delivery driver',
    'delivery guy (mcd)': 'delivery driver',
    'servics crew mcd': 'service crew',
    'garb driver': 'delivery driver',
    'maintenance technician': 'maintenance staff',
    'service crew mcd': 'service crew',
    'application support specialist': 'it support',
    'property executive': 'real estate agent',
    'digital assistant engineer': 'engineer',
    'human resource': 'hr & recruitment',
    'executive': 'executive',
    'student': 'student',
    'administrative specialist': 'admin',
    'viewer experience advocate': 'customer service agent',
    'customer service agent (cable)': 'customer service agent',
    'process engineer': 'engineer',
    'project leader assistant': 'assistant manager',
    'chef': 'chef',
    'finance analyst': 'banking & finance',
    'audit staff': 'auditor',
    'customer service agent': 'customer service agent',
    'cs agent': 'customer service agent',
    'youtuberr': 'media & content creator',
    'field engineer': 'engineer',
    'district service director': 'director',
    'accounts executive': 'accountant',
    'executive account': 'accountant',
    'associate specialist': 'specialist',
    'content moderator': 'media & content creator',
    'art tutor': 'education professional',
    'customer service': 'customer service agent',
    'senior actor': 'media & content creator',
    'team leader': 'team leader',
    'youtuber': 'media & content creator',
    'clinical skills': 'healthcare professional',
    'nurse': 'nurse',
    'information technology (it)': 'it support',
    'banker': 'banking & finance',
    'customer service agent (cable)': 'customer service agent',
    'customer service executives': 'customer service agent',
    'accounts admin': 'accountant',
    'business onwer': 'entrepreneur',
    'maths teacher': 'teacher',
    'hr': 'hr & recruitment',
    'lawyer': 'lawyer',
    'data analyst': 'data analyst',
    'project manager': 'manager',
    'administration': 'admin',
    'cust service': 'customer service agent',
    'software engineering': 'software engineer',
    'call centre agent': 'customer service agent',
    'customer service representative': 'customer service agent',
    'educator': 'education professional',
    'software developer': 'software engineer',
    'senior customer service representative': 'customer service agent',
    'product management': 'manager',
    'unemployed': 'unemployed',
    'service crew supervisor': 'service crew',
    'actor/singer/ assistant director': 'media & content creator',
    'assistant director': 'media & content creator',
    'music director': 'media & content creator',
    'accounts assistant': 'accountant',
    'restaurant owner': 'entrepreneur',
    'service crew (gsc)': 'service crew',
    'nursing': 'nurse',
    'camera man': 'media & content creator',
    'administrative assistant': 'admin',
    'real estate agent': 'real estate agent',
    'sales admin executive': 'sales agent',
    'sales support/personal assistant': 'admin',
    'front desk team leader': 'team leader',
    'custome service agent': 'customer service agent',
    'teacher': 'teacher',
    'presentation director': 'director',
    'singer': 'media & content creator',
    'runner': 'logistics staff',
    'learning development partner': 'trainer',
    'admin': 'admin',
    'shop': 'retail staff',
    'grab driver':'delivery driver',
    'it':'it support'
}


# Clean the job titles using the mapping
df['Job_Title'] = df['Job_Title'].apply(lambda x: job_title_mapping.get(str(x).strip().lower(), x) if isinstance(x, str) else x)

# Get value counts for cleaned data
cleaned_job_counts = df['Job_Title'].value_counts()

# Print cleaned data
print(cleaned_job_counts)
# Out:
# Job_Title
# customer service agent              69
# service crew                        19
# unemployed                          17
# media & content creator             14
# delivery driver                     13
# admin                               11
# accountant                          11
# team leader                         10
# nurse                                8
# teacher                              7
# manager                              7
# doctor                               5
# healthcare professional              5
# hr & recruitment                     5
# director                             5
# entrepreneur                         4
# engineer                             4
# actor                                3
# graphic designer                     3
# chef                                 3
# hospitality staff                    3
# sales agent                          2
# maintenance staff                    2
# supervisor                           2
# ...

# %%
# Define the job title to category mapping
job_category_mapping = {
    'customer service agent': 'customer service',
    'service crew': 'hospitality & service',
    'unemployed': 'unemployed',
    'media & content creator': 'media & entertainment',
    'delivery driver': 'transportation & logistics',
    'admin': 'administration',
    'accountant': 'finance & accounting',
    'team leader': 'management',
    'nurse': 'healthcare',
    'teacher': 'education',
    'manager': 'management',
    'doctor': 'healthcare',
    'healthcare professional': 'healthcare',
    'hr & recruitment': 'human resources',
    'director': 'management',
    'entrepreneur': 'business & entrepreneurship',
    'engineer': 'engineering',
    'actor': 'media & entertainment',
    'graphic designer': 'creative & design',
    'chef': 'hospitality & service',
    'hospitality staff': 'hospitality & service',
    'sales agent': 'sales & marketing',
    'maintenance staff': 'technical & maintenance',
    'supervisor': 'management',
    'customer service agent executive': 'customer service',
    'software engineer': 'IT & software development',
    'grab food driver': 'transportation & logistics',
    'real estate agent': 'real estate',
    'retail staff': 'retail',
    'education professional': 'education',
    'it support': 'IT & software development',
    'data analyst': 'data & analytics',
    'banking & finance': 'finance & accounting',
    'trainer': 'training & development',
    'warehouse staff': 'transportation & logistics',
    'pharmacy staff': 'healthcare',
    'marketing executive': 'sales & marketing',
    'lawyer': 'legal',
    'intern': 'student',
    'student': 'student',
    'executive': 'management',
    'logistics staff': 'transportation & logistics',
    'fashion & textile': 'creative & design',
    'unknown': 'unknown',
    'music & arts': 'media & entertainment',
    'business support': 'business & entrepreneurship',
    'insurance agent': 'finance & accounting',
    'auditor': 'finance & accounting',
    'assistant manager': 'management',
    'specialist': 'specialized professions',
    'technician': 'technical & maintenance'
}

# Apply the mapping to the 'Job_Title' column, handling NaN values
df['Job_Category'] = df['Job_Title'].apply(lambda x: job_category_mapping.get(str(x).strip().lower(), 'Other') if pd.notna(x) else 'unknown')

# Get value counts for the grouped categories
grouped_job_counts = df['Job_Category'].value_counts()

# Print grouped data
print(grouped_job_counts)
# Out:
# Job_Category
# customer service               71
# management                     26
# hospitality & service          25
# healthcare                     19
# media & entertainment          18
# unemployed                     17
# transportation & logistics     17
# finance & accounting           15
# administration                 11
# unknown                        10
# education                       9
# human resources                 5
# business & entrepreneurship     5
# IT & software development       4
# creative & design               4
# engineering                     4
# technical & maintenance         3
# sales & marketing               3
# student                         2
# real estate                     2
# data & analytics                2
# retail                          2
# training & development          2
# specialized professions         1
# legal                           1
# Name: count, dtype: int64

# %%
import pandas as pd
import uuid

# Assuming df is your DataFrame
df['Unique_ID'] = [str(uuid.uuid4()) for _ in range(len(df))]

# %%
df.head()
# Out:
#                  Age  Gender          Education  \
# 0  26 - 30 years old  Female  Bachelor's Degree
# 1  20 - 25 years old    Male    Master's Degree
# 2  26 - 30 years old  Female    Master's Degree
# 3      35+ years old  Female                SPM
# 4  20 - 25 years old  Female  Bachelor's Degree
#
#                                  Major Employment_Status  \
# 0  Business, Management, and Marketing          Employed
# 1  Business, Management, and Marketing          Employed
# 2  Business, Management, and Marketing          Employed
# 3         Medicine and Health Sciences          Employed
# 4                            Education          Employed
#
#                                   Industry               Job_Title  \
# 0                  Hospitality and Tourism  customer service agent
# 1  Media, Entertainment, and Communication  customer service agent
# 2  Media, Entertainment, and Communication             team leader
# ...

# %%
# Get the value counts
desired_role_counts = df['Desired_Roles'].value_counts()

# Print each job title and count
for job, count in desired_role_counts.items():
    print(f"{job}: {count}")
# Out:
# Na: 46
# -: 14
# Manager: 6
# Noo: 4
# Not sure: 4
# na: 4
# Business : 4
# No: 3
# Not at the moment : 2
# Ntg: 2
# Nooo: 2
# Marketing : 2
# NONE: 2
# none: 2
# Designer : 2
# Nope: 2
# Not applicable : 2
# HR: 2
# Business: 2
# non: 1
# Teacher: 1
# Sales: 1
# None : 1
# Engineering : 1
# Restaurant : 1
# Supervisor position: 1
# HR Executive & Marketing : 1
# If I were to transition to a new career, I would be interested in owning a clothing boutique business and taking on the role of Creative Director.: 1
# Producer: 1
# Accountant : 1
# Yes: 1
# IT: 1
# Customer service, safety officer,: 1
# Automotive, Buisness : 1
# Engineering based industries: 1
# Private industries: 1
# Finance related positions : 1
# Cinematic Arts: 1
# Administration: 1
# Finance: 1
# Law : 1
# Travels : 1
# Oil and gas industry : 1
# IT'BUSSINESS : 1
# dont know: 1
# Farm: 1
# Data scientist: 1
# NIL: 1
# Discipline : 1
#  entrepreneur: 1
# Team leader : 1
# Government sectors : 1
# ...

# %%
# Lowercase and strip spaces
df['Desired_Roles'] = df['Desired_Roles'].str.lower().str.strip()

desired_role_category_mapping = {
    # Customer Service & Administrative
    'customer service': 'customer service',
    'customer service, safety officer': 'customer service',
    'customer relation job': 'customer service',
    'office admin': 'administration',
    'admin': 'administration',
    'administration': 'administration',

    # Sales & Marketing
    'sales': 'sales & marketing',
    'sales person or pr': 'sales & marketing',
    'sales and marketing': 'sales & marketing',
    'marketing': 'sales & marketing',
    'marketing executive': 'sales & marketing',
    'public relations': 'sales & marketing',

    # Finance & Accounting
    'finance': 'finance & accounting',
    'finance related positions': 'finance & accounting',
    'banking': 'finance & accounting',
    'accountant': 'finance & accounting',
    'taxation': 'finance & accounting',
    'auditor': 'finance & accounting',

    # HR & Training
    'hr': 'human resources',
    'hr management': 'human resources',
    'hr, business owner': 'human resources',
    'hr executive & marketing': 'human resources',
    'training & development and channel management': 'human resources',
    'trainer': 'human resources',
    'teacher, trainer': 'education',

    # IT & Data Science
    'it': 'IT & software development',
    'it support': 'IT & software development',
    "it'bussiness": 'IT & software development',
    'software engineer': 'IT & software development',
    'data scientist': 'data & analytics',
    'senior data analyst': 'data & analytics',
    'research, data science, robotics, cybersecurity, product management, software engineering, human-computer interaction (hci), healthcare technology, autonomous systems, or education technology.': 'IT & software development',

    # Healthcare & Medical
    'medical': 'healthcare',
    'doctor': 'healthcare',
    'nurse': 'healthcare',
    'pharmacy staff': 'healthcare',
    'healthcare professional': 'healthcare',
    'to a permanent nurse': 'healthcare',
    'more psychology related': 'healthcare',

    # Engineering & Technical
    'engineering': 'engineering',
    'engineering based industries': 'engineering',
    'assistant engineer': 'engineering',
    'aircraft': 'engineering',
    'automotive, buisness': 'engineering',
    'oil and gas industry': 'engineering',

    # Creative & Media
    'graphic designing': 'creative & design',
    'designer': 'creative & design',
    'if i were to transition to a new career, i would be interested in owning a clothing boutique business and taking on the role of creative director.': 'creative & design',
    'fashion & textile': 'creative & design',
    'media': 'media & entertainment',
    'cinematic arts': 'media & entertainment',
    'producer': 'media & entertainment',
    'might be a storyteller': 'media & entertainment',

    # Business & Management
    'business': 'business & management',
    'own business': 'business & management',
    'self business': 'business & management',
    'business, manager, food court': 'business & management',
    'business management': 'business & management',
    'entrepreneur': 'business & management',
    'management': 'business & management',
    'team leader': 'business & management',
    'team leader (tl)': 'business & management',
    'team leader(tl)': 'business & management',
    'team leader or ceo of the company': 'business & management',
    'business support': 'business & management',
    'management consulting': 'business & management',
    'customer service , business': 'business & management',
    'as a manager': 'business & management',
    'building manager': 'business & management',

    # Hospitality & Service
    'restaurant': 'hospitality & service',
    'food, business': 'hospitality & service',
    'culinary': 'hospitality & service',
    'service crew': 'hospitality & service',
    'customer service, safety officer,': 'hospitality & service',
    'customer service': 'hospitality & service',

    # Logistics & Supply Chain
    'logistic': 'transportation & logistics',
    'supply management': 'transportation & logistics',
    'logistics staff': 'transportation & logistics',
    'delivery driver': 'transportation & logistics',

    # Real Estate & Architecture
    'real estate agent': 'real estate',
    'architecture': 'real estate',

    # Education
    'teacher': 'education',
    'teaching': 'education',
    'education professional': 'education',

    # Legal
    'lawyer': 'legal',
    'law': 'legal',

    # Other Fields
    'government sectors': 'government',
    'politics': 'government',
    'zoologist': 'science & research',
    'farm': 'agriculture',
    'discipline': 'unspecified',
    'immigration agency': 'government',
    'research': 'science & research',
    
    # Undefined / Miscellaneous
    'not sure': 'unspecified',
    'not applicable': 'NA',
    'none': 'NA',
    'no': 'NA',
    'nope': 'NA',
    'nothing': 'NA',
    'na': 'NA',
    'ntg': 'NA',
    'haven’t think about it': 'unspecified',
    'unknown': 'NA',
    'n/a': 'NA',
    '-': 'NA',
    'noo': 'NA',
    'nooo': 'NA',
    'not at the moment': 'NA',
    'yes': 'unspecified',
    'non': 'NA',
    'dont know': 'unspecified',
    'a better job': 'unspecified',
    'a good job': 'unspecified',
    'nil': 'NA',
    'a better job with benefits': 'unspecified',
    'nooooooo': 'NA',
    "haven't think about it":'unspecified',
    'nonr': 'NA',
    '.': 'NA',
    'a better job without stress':'unspecified',
    'nane': 'NA',
    'none, im happy with what i am': 'NA',
    'better work without any problem':'unspecified',
    'fixed working, company travel, annual leave,and other benefit':'unspecified',
    'dftt':'unspecified',
    'remote work':'unspecified',
    'same': 'NA',
    'noneee': 'NA',
    'agency type of business':'unspecified'
}
# Apply mapping function to categorize desired roles
df['Desired_Roles'] = df['Desired_Roles'].apply(lambda x: desired_role_category_mapping.get(str(x).strip().lower(), x) if isinstance(x, str) else x)

# Get the value counts
desired_role_counts = df['Desired_Roles'].value_counts()

# Print each job title and count
for job, count in desired_role_counts.items():
    print(f"{job}: {count}")
# Out:
# NA: 98
# business & management: 23
# unspecified: 17
# human resources: 6
# sales & marketing: 6
# engineering: 6
# manager: 6
# finance & accounting: 6
# hospitality & service: 5
# administration: 4
# education: 4
# healthcare: 4
# creative & design: 4
# media & entertainment: 4
# IT & software development: 3
# government: 3
# data & analytics: 2
# transportation & logistics: 2
# art and design: 1
# travels: 1
# supervisor position: 1
# real estate: 1
# private industries: 1
# legal: 1
# customer service: 1
# science & research: 1
# agriculture: 1

# %%
# Save the DataFrame to an Excel file
df.to_excel('Job_Satisfaction_MY.xlsx', index=False)

# Generate a download link for the Excel file
from IPython.display import FileLink
FileLink('Job_Satisfaction_MY.xlsx')
# Out:
# C:\Users\User\Downloads\Skill Based Career Transition Recomendation System\Job_Satisfaction_MY.xlsx
